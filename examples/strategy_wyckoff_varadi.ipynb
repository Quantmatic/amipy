# %%
"""
Created on Mon Jun  5 07:53:15 2017
@author: github.com/Quantmatic
"""

import datetime
import TTR
import amipy
from strategy_wyckoff_varadi import VolatilityAdjustedStrategy

# %%
START_DATE = datetime.datetime(2006, 1, 2)

# %%
END_DATE = datetime.datetime(2016, 12, 31)

# %%
INSTRUMENTS = [{'SYMBOL': '@ES#1H', 'DBASE': 'FUTURE', #*** e-mini sp500 60min continuous ***#
                'EQUITY': 100000, 'MARGIN': 5500,
                'TICKSIZE': 0.25, 'TICKVALUE': 12.5,
                'RISK': 0.07, 'WARMUP_BARS': 500},
               {'SYMBOL': '@NQ#1H', 'DBASE': 'FUTURE', #*** e-mini Nasdaq 60min continuous ***#
                'EQUITY': 100000, 'MARGIN': 5500,
                'TICKSIZE': 0.25, 'TICKVALUE': 5.0,
                'RISK': 0.07, 'WARMUP_BARS': 500},
               {'SYMBOL': '@TY#1H', 'DBASE': 'FUTURE', #*** 10-Year Note 60min continuous ***#
                'EQUITY': 200000, 'MARGIN': 5500,
                'TICKSIZE': 0.005, 'TICKVALUE': 15.625,
                'RISK': 0.04, 'WARMUP_BARS': 500}]

# %%
for inst in INSTRUMENTS:
    context = type('context', (object, ), {'symbol': '', 'dbase': ''})
    context.symbol = inst['SYMBOL']
    context.dbase = inst['DBASE']
    context.starting_equity = inst['EQUITY']
    context.margin_required = inst['MARGIN']
    context.tick_size = inst['TICKSIZE']
    context.tick_value = inst['TICKVALUE']
    context.risk = inst['RISK']
    context.warmup_bars = inst['WARMUP_BARS']

    OHLC = amipy.mongo_grab(context.symbol, context.dbase, START_DATE, END_DATE)

    STRAT = VolatilityAdjustedStrategy(context)

    STRAT.Run(OHLC)
# Out:
# Symbol: @ES#1H
# Collection retrived in 0.511146068573 seconds. 67181 Bars.
#
# Backtest finished in 0.983690977097 seconds.
#
# Starting Equity: 100000.0
# Final Equity: 1942512.5
# Profitable trades: 511
# Losing trades: 151
# Winrate: 77.19%
# Short winrate: 74.44%
# Long winrate: 78.59%
# Sharpe: 4.89
# Sortino: 5.91
# CAGR: 30.98%
# Profit factor: 4.81
# Consecutive losses: 5
# Max drawdown: 15.43%
# Stats for equity from 2006-02-03 00:00:00 - 2016-11-08 00:00:00
# Annual risk-free rate considered: 5.00%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 1842.51%            4.89  31.74%  -15.43%
#
# Annualized Returns:
# mtd    3m      6m      ytd     1y      3y      5y      10y     incep.
# -----  ------  ------  ------  ------  ------  ------  ------  --------
# 5.19%  12.72%  29.47%  57.01%  68.53%  48.19%  41.86%  33.64%  31.74%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  4.89     1.79       1.37
# mean    107.12%  30.99%     35.05%
# vol     20.89%   14.59%     21.96%
# skew    -1.46    2.27       0.38
# kurt    18.70    16.55      -1.53
# best    9.04%    30.64%     68.46%
# worst   -11.48%  -10.06%    10.85%
#
# Drawdowns:
# max      avg       # days
# -------  ------  --------
# -15.43%  -2.33%      36.5
#
# Misc:
# ---------------  -------
# avg. up month    3.82%
# avg. down month  -2.51%
# up year %        100.00%
# 12m up %         88.24%
# ---------------  -------
#
#
#   Year    Jan    Feb    Mar    Apr    May     Jun    Jul    Aug    Sep    Oct    Nov    Dec    YTD
# ------  -----  -----  -----  -----  -----  ------  -----  -----  -----  -----  -----  -----  -----
#   2006   0     -0.12   0     -2.58   3.24    2.04   1.94  -0.14   0      0      2.33   0.67   7.49
#   2007   0.81   1.77   4.91   1.04   0.8    -0.98  -4.9    6.08   3.03   2.71  -2.41   1.31  14.56
#   2008   3.82   1.36   0     -2.46   1.86    4.33  -1.42   1.96   4.71  30.64  11.31   0.92  68.46
#   2009   2.8    0.72   0.5    1.92  -2.69   -0.77   3.97   2.74  -2.4    0.55   2.45   1.04  11.16
#   2010   1.3   -0.8    4.04   2.33  -6.38   -4.7    2.06  -2.9    5.19   5.28   4.1    1.63  10.85
#   2011   3.91   3.35   0.53   1.09  -1.87    5.25   4.55   0.17   2.99  10.13   5.2    1.79  43.38
#   2012   4.28   3.92   5.74   2.1   -1.75  -10.06   3.89   2.59   1.32   3.85   5.39   3.7   26.73
#   2013   0      0     -0.59   3.4    3.82   -2.75   4.07   4.04   4.67   7.74   5.66   1.74  36.22
#   2014   0      0     -0.92   2.94   3.28    0      0      0      0      0      2.55   5.35  13.8
#   2015   1.19   4.73   4.38   6.87   2.5     5.26   2.4    0.68   5.99   7.6    4      4.48  62.93
#   2016  -4.27  11.59   8.4    4.73   1.71    7.39   2.65   2.43   2.89   4.14   5.19   0     57.01
# Symbol: @NQ#1H
# Collection retrived in 0.527374982834 seconds. 65264 Bars.
#
# Backtest finished in 0.907356977463 seconds.
#
# Starting Equity: 100000.0
# Final Equity: 257845.0
# Profitable trades: 371
# Losing trades: 177
# Winrate: 67.7%
# Short winrate: 54.61%
# Long winrate: 72.73%
# Sharpe: 1.78
# Sortino: 2.00
# CAGR: 9.24%
# Profit factor: 1.60
# Consecutive losses: 8
# Max drawdown: 14.96%
# Stats for equity from 2006-05-16 00:00:00 - 2016-12-01 00:00:00
# Annual risk-free rate considered: 5.00%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 157.85%             1.79  9.40%   -14.96%
#
# Annualized Returns:
# mtd     3m     6m     ytd     1y      3y      5y      10y    incep.
# ------  -----  -----  ------  ------  ------  ------  -----  --------
# -2.82%  2.02%  7.50%  14.44%  11.80%  12.60%  10.76%  9.42%  9.40%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  1.79     0.50       0.84
# mean    41.91%   10.49%     9.58%
# vol     20.69%   11.24%     5.45%
# skew    -1.63    -0.30      -0.05
# kurt    13.92    1.53       -1.04
# best    8.38%    10.99%     16.92%
# worst   -9.76%   -9.74%     0.87%
#
# Drawdowns:
# max      avg       # days
# -------  ------  --------
# -14.96%  -3.62%     77.61
#
# Misc:
# ---------------  -------
# avg. up month    2.63%
# avg. down month  -2.41%
# up year %        100.00%
# 12m up %         81.20%
# ---------------  -------
#
#
#   Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov    Dec    YTD
# ------  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----  -----
#   2006   0      0      0      0     -0.24  -2.64  -2.92   4.34  -0.59   3.25   3.54  -0.07   4.46
#   2007  -0.14   1.61   2.03   0.62  -0.1    2.75   2.04  -0.92   3.47   3.9   -5.52   0.82  10.68
#   2008  -2.08  -1.98   0      3.61   2.93   1.8    0     -0.33  -6.38  10.99   8.86  -0.6   16.78
#   2009  -1.88   0      0      2.64   0.72   0.73  -0.89   3.7    1.32   0.93  -3.68   1.24   4.73
#   2010   1.06   0.52   0.78   2.89  -4.73  -3.62   2.09   1.92   1.71   3.16   0.87   0.15   6.66
#   2011   0.84   1.93  -3.31   2.31   0.61   0.47   0.99  -6.94   1.26   3.16   1.02  -1.03   0.87
#   2012   2.15   3.37   5.68  -0.82  -6.08  -6.57   2.85   0      0     -2.49   2.98   1.76   2.08
#   2013   2.52   1.36   0      7.69   0.33   2.47   1.44   0      0     -0.13  -3.23   2.42  15.5
#   2014   0      3.15  -4.91   4.3    3.68   0      0      2.48   0      0      2.16   5.5   17.14
#   2015  -0.36   3.4    3.31   1.29  -0.6   -1.2    3.57   0.46  -9.74   8.47   2.36  -1.33   8.94
#   2016   0.26   4      2.56  -3.54   3.21   5.37   0      0      0      0      0     -2.82   9.02
# Symbol: @TY#1H
# Collection retrived in 0.468899011612 seconds. 64085 Bars.
#
# Backtest finished in 0.960057973862 seconds.
#
# Starting Equity: 200000.0
# Final Equity: 641878.90625
# Profitable trades: 311
# Losing trades: 160
# Winrate: 66.03%
# Short winrate: 53.85%
# Long winrate: 70.67%
# Sharpe: 1.73
# Sortino: 2.10
# CAGR: 11.67%
# Profit factor: 1.34
# Consecutive losses: 7
# Max drawdown: 26.95%
# Stats for equity from 2006-07-24 00:00:00 - 2016-12-26 00:00:00
# Annual risk-free rate considered: 5.00%
# Summary:
# Total Return      Sharpe  CAGR    Max Drawdown
# --------------  --------  ------  --------------
# 220.94%             1.73  11.83%  -26.95%
#
# Annualized Returns:
# mtd    3m     6m      ytd     1y      3y     5y     10y     incep.
# -----  -----  ------  ------  ------  -----  -----  ------  --------
# 0.96%  1.69%  -5.93%  -4.65%  -4.65%  4.17%  9.31%  11.45%  11.83%
#
# Periodic:
#         daily    monthly    yearly
# ------  -------  ---------  --------
# sharpe  1.73     0.61       0.38
# mean    58.30%   14.68%     13.07%
# vol     30.89%   16.16%     21.38%
# skew    -0.94    -0.61      1.57
# kurt    4.10     0.87       3.86
# best    7.05%    12.54%     64.73%
# worst   -8.38%   -12.73%    -14.86%
#
# Drawdowns:
# max      avg       # days
# -------  ------  --------
# -26.95%  -6.22%    123.76
#
# Misc:
# ---------------  ------
# avg. up month    3.61%
# avg. down month  -4.02%
# up year %        80.00%
# 12m up %         66.96%
# ---------------  ------
#
#
#   Year    Jan    Feb     Mar    Apr    May    Jun    Jul    Aug    Sep     Oct    Nov     Dec     YTD
# ------  -----  -----  ------  -----  -----  -----  -----  -----  -----  ------  -----  ------  ------
#   2006   0      0       0      0      0      0      0      3.05   1.14   -0.35   3.79    0.7     8.56
#   2007   0.92   1.4     1.28   1.22   0      0      1.66  -0.29   1.42    1.57   2.12    0      11.86
#   2008   0      1.07    0      0     -3.87   2.75  -0.82   4.93   0.18    4.47   1.15    0       9.98
#   2009   0      0       8.04   2.06  -0.67   9.56  -1.04   0      6.08  -12.73  -4.47   -2.81    2.08
#   2010   2.29  12.54    4.25   1.19   6.42   7.35   7.11   4.29  -7.9     1.73  -3.81  -12.26   22.53
#   2011   2.16   1.51  -10.91   8.07   3.06   0.78  -1.59   7.25   4.22    3.5    0       3.88   22.64
#   2012   7.58   6.76    6.65   9.81   9.36   0.66   4.37   4.34   0.21   -1.73   1.79    1.91   64.73
#   2013   0.5    1.86    3.9    0      0     -1.72   2.8   -6.52  -4.02    5.72  -9.01   -9.42  -15.99
#   2014  -2.58   7.41   -2.29   8.11   2.31   5.14   2.2    3.47   0.69   -6.89  -2.42   -4.18   10.21
#   2015   0     -5.05   -1.08   5.09   1.97   3.35  -2.06   5.79   2.81    1.14  -6.74    2.84    7.47
#   2016   4.42   0.24   -1.59  -6.48   5.21   0      0      0.81   1.05   -3.46   2.39    0.96    3.04
